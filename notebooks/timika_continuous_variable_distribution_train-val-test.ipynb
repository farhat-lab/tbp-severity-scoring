# %%
# Define bins
bin_edges = np.arange(0, 141, 10)  # Bins from 0 to 140 by 10
# Bin the data
available_images_train_df['binned_timika'] = pd.cut(available_images_train_df['timika'], bins=bin_edges)

# %%
bin_counts = available_images_train_df['binned_timika'].value_counts(sort=False)

# %%
# Plot
plt.figure(figsize=(10, 6))
bin_counts.plot(kind='bar')
plt.title('Frequency of Timika scores')
plt.xlabel('Bins')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--')
plt.show()

# %%
# Define bins
bin_edges = np.arange(0, 141, 10)  # Bins from 0 to 140 by 10
# Bin the data
available_images_val_df['binned_timika'] = pd.cut(available_images_val_df['timika'], bins=bin_edges)

# %%
bin_counts = available_images_val_df['binned_timika'].value_counts(sort=False)

# %%
# Plot
plt.figure(figsize=(10, 6))
bin_counts.plot(kind='bar')
plt.title('Frequency of Timika scores')
plt.xlabel('Bins')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--')
plt.show()

# %%
# Define bins
bin_edges = np.arange(0, 141, 10)  # Bins from 0 to 140 by 10
# Bin the data
available_images_test_df['binned_timika'] = pd.cut(available_images_test_df['timika'], bins=bin_edges)

# %%
bin_counts = available_images_test_df['binned_timika'].value_counts(sort=False)

# %%
# Plot
plt.figure(figsize=(10, 6))
bin_counts.plot(kind='bar')
plt.title('Frequency of Timika scores')
plt.xlabel('Bins')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--')
plt.show()
